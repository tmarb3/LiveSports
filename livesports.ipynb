# %% [markdown]
# <a href="https://colab.research.google.com/github/tmarb3/LiveSports/blob/main/livesports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd 

url = "https://sportspage-feeds.p.rapidapi.com/games"

headers = {
	"X-RapidAPI-Key": "0aa12ed700msh286c84246dadd4ep1f4a54jsn34f34a0a1f45",
	"X-RapidAPI-Host": "sportspage-feeds.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

# %%
data = json.loads(response.text)

# %%
type(data)
# Out:
# dict

# %%
data
# Out:
# {'games': 10,
#  'results': [{'details': {'conferenceGame': True,
#     'divisionGame': False,
#     'league': 'MLB',
#     'season': 2022,
#     'seasonType': 'regular'},
#    'gameId': 280655,
#    'lastUpdated': '2022-06-23T05:18:10.141Z',
#    'odds': [{'lastUpdated': '2022-06-23T05:15:55.918Z',
#      'moneyline': {'current': {'awayOdds': 120, 'homeOdds': -136},
#       'open': {'awayOdds': 102, 'homeOdds': -118}},
#      'openDate': '2022-06-22T19:55:26.159Z',
#      'spread': {'current': {'away': 1.5,
#        'awayOdds': -185,
#        'home': -1.5,
#        'homeOdds': 160},
#       'open': {'away': 1.5, 'awayOdds': -200, 'home': -1.5, 'homeOdds': 170}},
#      'total': {'current': {'overOdds': -120, 'total': 8, 'underOdds': 100},
#       'open': {'overOdds': -100, 'total': 8.5, 'underOdds': -120}}}],
#    'schedule': {'date': '2022-06-23T16:10:00.000Z', 'tbaTime': False},
#    'status': 'scheduled',
#    'summary': 'Colorado Rockies @ Miami Marlins',
# ...

# %%
df = pd.json_normalize(data['results'])

df[df['status'] != "final"]
# Out:
#                                     summary     status  \
# 0          Colorado Rockies @ Miami Marlins  scheduled
# 1     San Francisco Giants @ Atlanta Braves  scheduled
# 2         Chicago Cubs @ Pittsburgh Pirates  scheduled
# 3     Los Angeles Dodgers @ Cincinnati Reds  scheduled
# 4     Cleveland Guardians @ Minnesota Twins  scheduled
# 5   St. Louis Cardinals @ Milwaukee Brewers  scheduled
# 6      Seattle Mariners @ Oakland Athletics  scheduled
# 7         Houston Astros @ New York Yankees  scheduled
# 8     Baltimore Orioles @ Chicago White Sox  scheduled
# 9  Philadelphia Phillies @ San Diego Padres  scheduled
#
#                 lastUpdated  gameId  \
# 0  2022-06-23T05:18:10.141Z  280655
# 1  2022-06-23T05:18:10.176Z  280658
# 2  2022-06-23T05:18:10.247Z  280661
# 3  2022-06-23T05:18:10.216Z  280664
# 4  2022-06-23T05:18:10.282Z  280686
# 5  2022-06-23T05:18:10.314Z  280669
# 6  2022-06-23T05:18:10.345Z  280673
# 7  2022-06-23T05:18:10.382Z  280677
# ...

# %%
df.transpose()
# Out:
#                                                                          0  \
# summary                                   Colorado Rockies @ Miami Marlins
# status                                                           scheduled
# lastUpdated                                       2022-06-23T05:18:10.141Z
# gameId                                                              280655
# odds                     [{'spread': {'open': {'away': 1.5, 'home': -1....
# schedule.date                                     2022-06-23T16:10:00.000Z
# schedule.tbaTime                                                     False
# details.league                                                         MLB
# details.seasonType                                                 regular
# details.season                                                        2022
# details.conferenceGame                                                True
# ...

# %%
df.to_csv('mlbgames.csv')

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
df.to_csv('mlbgames.csv')
# !cp mlbgames.csv "drive/My Drive/"
